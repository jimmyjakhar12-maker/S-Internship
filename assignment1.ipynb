# %%
# Student Marks Calculator

print("=" * 45)
print("       STUDENT MARKS CALCULATOR")
print("=" * 45)

name  = input("\nEnter Student Name  : ")
cls   = input("Enter Class         : ")

print("\nEnter marks for 5 subjects (out of 100):")
subject_names = ["Subject 1", "Subject 2", "Subject 3", "Subject 4", "Subject 5"]
marks = []

for subject in subject_names:
    while True:
        try:
            mark = float(input(f"  {subject} : "))_
            if 0 <= mark <= 100:
                marks.append(mark)
                break
            else:
                print("  ⚠  Please enter a value between 0 and 100.")
        except ValueError:
            print("  ⚠  Invalid input. Please enter a numeric value.")

total_marks     = sum(marks)
max_marks       = 500         
percentage      = (total_marks / max_marks) * 100

if percentage >= 90:
    grade = "A+"
elif percentage >= 80:
    grade = "A"
elif percentage >= 70:
    grade = "B"
elif percentage >= 60:
    grade = "C"
elif percentage >= 50:
    grade = "D"
else:
    grade = "F"

result = "PASS" if percentage >= 35 else "FAIL"

print("\n" + "=" * 45)
print("              RESULT CARD")
print("=" * 45)
print(f"  Student Name  : {name}")
print(f"  Class         : {cls}")
print("-" * 45)
print(f"  {'Subject':<12} {'Marks':>10} / 100")
print("-" * 45)
for subject, mark in zip(subject_names, marks):
    print(f"  {subject:<12} {mark:>10.1f}")
print("-" * 45)
print(f"  {'Total Marks':<12} {total_marks:>10.1f} / {max_marks}")
print(f"  {'Percentage':<12} {percentage:>9.2f}%")
print(f"  {'Grade':<12} {'':>10}{grade}")
print(f"  {'Result':<12} {'':>10}{result}")
print("=" * 45)
# Out:
# =============================================
#        STUDENT MARKS CALCULATOR
# =============================================
#
# Enter marks for 5 subjects (out of 100):
#   ⚠  Invalid input. Please enter a numeric value.
#
# =============================================
#               RESULT CARD
# =============================================
#   Student Name  : hardik
#   Class         : 12
# ---------------------------------------------
#   Subject           Marks / 100
# ---------------------------------------------
#   Subject 1          24.0
#   Subject 2          56.0
#   Subject 3          76.0
#   Subject 4          78.0
#   Subject 5          56.0
# ---------------------------------------------
#   Total Marks       290.0 / 500
#   Percentage       58.00%
#   Grade                  D
#   Result                 PASS
# =============================================

# %%
str1 = input("Enter first string: ")
str2 = input("Enter second string: ")
result = str1 + " " + str2
print(result)



print("lower()      :", result.lower())
print("upper()      :", result.upper())
print("title()      :", result.title())
print("swapcase()   :", result.swapcase())
print("capitalize() :", result.capitalize())
print("casefold()   :", result.casefold())
print("center()     :", result.center(50, '*'))
print("count('a')   :", result.count('a'))
print("endswith('!'):", result.endswith('!'))
print("find('a')    :", result.find('a'))
print("isalnum()    :", result.isalnum())
print("isdigit()    :", result.isdigit())
print("isnumeric()  :", result.isnumeric())
print("isspace()    :", result.isspace())
print("replace()    :", result.replace('e', '@'))
# Out:
# Hello how are you I am fine
# lower()      : hello how are you i am fine
# upper()      : HELLO HOW ARE YOU I AM FINE
# title()      : Hello How Are You I Am Fine
# swapcase()   : hELLO HOW ARE YOU i AM FINE
# capitalize() : Hello how are you i am fine
# casefold()   : hello how are you i am fine
# center()     : ***********Hello how are you I am fine************
# count('a')   : 2
# endswith('!'): False
# find('a')    : 10
# isalnum()    : False
# isdigit()    : False
# isnumeric()  : False
# isspace()    : False
# replace()    : H@llo how ar@ you I am fin@

# %%
x = 10
print("Initial value of x =", x)
x += 5
print("After x += 5  :", x)
x -= 3
print("After x -= 3  :", x)
x *= 2
print("After x *= 2  :", x)
x /= 4
print("After x /= 4  :", x)
x %= 3
print("After x %= 3  :", x)
x **= 2
print("After x **= 2 :", x)
x //= 2
print("After x //= 2 :", x)
# Out:
# Initial value of x = 10
# After x += 5  : 15
# After x -= 3  : 12
# After x *= 2  : 24
# After x /= 4  : 6.0
# After x %= 3  : 0.0
# After x **= 2 : 0.0
# After x //= 2 : 0.0

# %%
name = input("Enter student name: ")
student_class = input("Enter class: ")

mark1 = float(input("Enter marks of Subject 1: "))
mark2 = float(input("Enter marks of Subject 2: "))
mark3 = float(input("Enter marks of Subject 3: "))
mark4 = float(input("Enter marks of Subject 4: "))
mark5 = float(input("Enter marks of Subject 5: "))

total = mark1 + mark2 + mark3 + mark4 + mark5
percentage = (total / 500) * 100

if percentage >= 60:
    grade = 'A'
elif percentage >= 50 and percentage < 60:
    grade = 'B'
elif percentage >= 40 and percentage < 50:
    grade = 'C'
elif percentage >= 33 and percentage < 40:
    grade = 'D'
else:
    grade = 'Fail'

print("\nResult")
print("Name       :", name)
print("Class      :", student_class)
print("Total Marks:", total)
print("Percentage :", percentage, "%")
print("Grade      :", grade)
# Out:
# Result
# Name       : Jitu
# Class      : 2
# Total Marks: 424.0
# Percentage : 84.8 %
# Grade      : A
