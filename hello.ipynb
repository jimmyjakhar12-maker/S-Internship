# %%
a = "This is python"
print(type(a))
# Out:
# <class 'str'>

# %%
a = 10
b= 10.0
print(type(a))
print(type(b))
# Out:
# <class 'int'>
# <class 'float'>

# %%
n1 = int(input("Enter first number 1 : "))
print(type(n1))
# Out:
# <class 'int'>

# %%
print("Hello world")
# Out:
# Hello world

# %%
a = "Hello"
b = "Jaat" 
print(a + " " + b)
# Out:
# Hello Jaat

# %%
a = "Hello"
b = "World"
print(a.upper())
# Out:
# HELLO

# %%
a = "Hello"
b = "Jaat"
print(a + " " + b)
print(a.lower())
print(a.upper())
print(a.title())    
print(a.capitalize())
# Out:
# Hello Jaat
# hello
# HELLO
# Hello
# Hello

# %%
a = 10
b = 20
print(a is not b)
# Out:
# True

# %%
a = 10
b = 20
print(a==b)
# Out:
# False

# %%
a = "This is python" 
b = "This " 
if (b not in a ):
    print("b is not a substring of a")

# %%
num = int(input("Enter a number : "))
for i in range(1, 11):
   table = num * i
   print(f"{num} x {i} = {table}")
# Out:
# 7 x 1 = 7
# 7 x 2 = 14
# 7 x 3 = 21
# 7 x 4 = 28
# 7 x 5 = 35
# 7 x 6 = 42
# 7 x 7 = 49
# 7 x 8 = 56
# 7 x 9 = 63
# 7 x 10 = 70

# %%
for i in range(10, 0, -1):
    for j in range(5):
        print(i, j, sep="__")
# Out:
# 10__0
# 10__1
# 10__2
# 10__3
# 10__4
# 9__0
# 9__1
# 9__2
# 9__3
# 9__4
# 8__0
# 8__1
# 8__2
# 8__3
# 8__4
# 7__0
# 7__1
# 7__2
# 7__3
# 7__4
# 6__0
# 6__1
# 6__2
# 6__3
# 6__4
# 5__0
# 5__1
# 5__2
# 5__3
# 5__4
# 4__0
# 4__1
# 4__2
# 4__3
# 4__4
# 3__0
# 3__1
# 3__2
# 3__3
# 3__4
# 2__0
# 2__1
# 2__2
# 2__3
# 2__4
# 1__0
# 1__1
# 1__2
# 1__3
# 1__4

# %%
l = [1, 2, 3, 4, 5]
d = {1:"abc"}
t = (10, 20, 30)
print(t[0])
# Out:
# 10

# %%
l = [1, 2, 3, 4, 5]
d = {1:"abc"}
t = (10 , 20, 30 , 20 , 30 , 40)
print (t.count(20))
# Out:
# 2

# %%
l = [1, 2, 3, 4, 5]
for i in l:
    print(i)
# Out:
# 1
# 2
# 3
# 4
# 5

# %%
l = [1, 2, 3, 4, 5]
d = {1:"abc"}
t = (10 , 20, 30 , 20 , 30 , 40)
print (t)
# Out:
# (10, 20, 30, 20, 30, 40)

# %%
t1 = (10, 20, 30)
t2 = (40, 50, 60)
print (t1 + t2)
# Out:
# (10, 20, 30, 40, 50, 60)

# %%
t1 = (10, 20, 30)
t2 = (40, 50, 60, ('a', 'b', 'c'))
t3 =    ('asdf.    ')*5
print(t3)
# Out:
# asdf.    asdf.    asdf.    asdf.    asdf.

# %%
t1 = (10, 20, 30)
t2 = (40, 50, 60)
print (t1 [1:3])
# Out:
# (20, 30)

# %%
t1 = (10, 20, 30)
t1 =  tuple
t2 = (1, 2, 3, 4, 5)
print (t1, type)
# Out:
# <class 'tuple'> <class 'type'>

# %%
t1 = (10, 20, 30 , 34, 45, 56, 67, 78, 89, 90)
print (sum(t1))
# Out:
# 519

# %%
t1 = (10, 20, 30 , 34, 45, 56, 67, 78, 89, 90)
print (min(t1))
# Out:
# 10

# %%
t1 = (10, 20, 30 , 34, 45, 56, 67, 78, 89, 90)
print (max(t1))
# Out:
# 90

# %%
t1 = (10, 20, 30 , 34, 45, 56, 67, 78, 89, 90)
print (t.count(56))
# Out:
# 0

# %%
t1 = (10, 20, 30 , 34, 45, 56, 67, 78, 89, 90)
print (t1.index(30))
# Out:
# 2

# %%
def function1(*city):
    print(city [2])

    function1("Delhi", "Mumbai", "Chennai", "Kolkata")

# %%
def my_country(country = "India"):
    print ("I am from " + country)

# %%
def function (city):
    print (city)

    function1("Delhi")
    print (function1)

# %%
def dob(*,n1):
    print(n1 *2)

    dob(n1=5)

# %%
def dob(a, b, /, *, c ,d):
    print(a+b+c+d)
    
dob(1, 2, c=30, d=40)
# Out:
# 73

# %%
def rec (k):
    if (k > 0):
        result = k + rec(k - 1)
        print(result)
    else:
        result = 0
    return result

# %%
file = open("file1.txt", "w")
file.write("This is my first file")
file.close()

# %%
file = open("file1.txt", "r")
print(file.read())
# Out:
# This is my first file

# %%
import csv 
with open("file1.csv", "w", newline="") as file:
    writer = csv.writer(file)
    writer.writerow(["Name", "Age", "City"])
    writer.writerow(["Alice", 30, "New York"])
    writer.writerow(["Bob", 25, "Los Angeles"])
    writer.writerow(["Charlie", 35, "Chicago"])

d = {"Name": "Alice", "Age": 30, "City": "New York"}
with open("file2.csv", "w", newline="") as file:
    writer = csv.DictWriter(file, fieldnames=d.keys())
    writer.writeheader()
    writer.writerow(d)

# %%
import csv 
with open("file1.csv", "w", newline="") as file:
    writer = csv.writer(file)
    writer.writerow(["Name", "Age", "City"])
    writer.writerow(["Alice", 30, "New York"])
    writer.writerow(["Bob", 25, "Los Angeles"])
    writer.writerow(["Charlie", 35, "Chicago"])

d = {"Name": "Alice", "Age": 30, "City": "New York"}
with open("file2.csv", "w", newline="") as file:
    writer = csv.DictWriter(file, fieldnames=d.keys())
    writer.writeheader()
    writer.writerow(d)    

with open("file1.csv", "r") as file:
    reader = csv.reader(file)
    for row in reader:
        print(row)
# Out:
# ['Name', 'Age', 'City']
# ['Alice', '30', 'New York']
# ['Bob', '25', 'Los Angeles']
# ['Charlie', '35', 'Chicago']

# %%
try:
    with open("file1.csv", "r") as file:
        reader = csv.reader(file)
        for row in reader:
            print(row)
except FileNotFoundError:
    print("The file was not found.")
# Out:
# ['Name', 'Age', 'City']
# ['Alice', '30', 'New York']
# ['Bob', '25', 'Los Angeles']
# ['Charlie', '35', 'Chicago']

# %%
    import requests

def weather_data(city):
    api_key = "your_api_key_here"  # Replace with your OpenWeatherMap API key
    url = f"https://api.openweathermap.org/data/2.5/weather?q={city}&appid=8d45a7a9c8d6f73011a81306379c0edf&units=metric"
    
    try:
        response = requests.get(url)
        response.raise_for_status()  # Check if the request was successful
        data = response.json()
        
        weather_info = {
            "coord":
            {
                "lon":77.6033,"lat":12.9762},
            "weather":[
                {"id":804,"main":"Clouds","description":"overcast clouds","icon":"04d"}
                ],"base":"stations","main":{"temp":297.27,"feels_like":297.98,"temp_min":296.54,"temp_max":298.05,"pressure":1014,"humidity":86,"sea_level":1014,"grnd_level":916},"visibility":10000,"wind":{"speed":4.45,"deg":275,"gust":6.47},"clouds":{"all":100},"dt":1779509212,"sys":{"type":2,"id":2094842,"country":"IN","sunrise":1779495781,"sunset":1779541794},"timezone":19800,"id":1277333,"name":"Bengaluru","cod":200}
    except requests.RequestException as e:
        print(f"An error occurred: {e}")

        city = input("Enter city name: ")
        weather_data(city)
# Out:
#   Cell In[9], line 1
#     import requests
#     ^
# IndentationError: unexpected indent
